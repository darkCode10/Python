# %% [markdown]
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# String

# %%
name:str="Muhammad Ahsaan"
print(name)
print(type(name))
print(id(name))
# Out:
# Muhammad Ahsaan
# <class 'str'>
# 2908147203504
